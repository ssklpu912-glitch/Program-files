# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
Ele_index = ('Li', 'Be', 'C', 'O', 'F', 'Ne' )
mass_1 = pd.Series([3, 4, 6, 8, 9, 10], index = Ele_index)
print(mass_1)
# Out:
# Li     3
# Be     4
# C      6
# O      8
# F      9
# Ne    10
# dtype: int64

# %%
print(mass_1)
mass_1.index = ('A', 'B', 'C', 'D', 'E', 'F')
mass_1
# Out:
# Li     3
# Be     4
# C      6
# O      8
# F      9
# Ne    10
# dtype: int64
# A     3
# B     4
# C     6
# D     8
# E     9
# F    10
# dtype: int64

# %%
mass_1[:4]
# Out:
# A    3
# B    4
# C    6
# D    8
# dtype: int64

# %%
print(mass_1)
index = ('A', 'B', 'C', 'D', 'E', 'F')
mass_2 = pd.Series([11, 13, 15, 20, 23, 26], index = index)
print(mass_2)
mass_3 = pd.concat([mass_2, mass_1])
mass_3
# Out:
# A     3
# B     4
# C     6
# D     8
# E     9
# F    10
# dtype: int64
# A    11
# B    13
# C    15
# D    20
# E    23
# F    26
# dtype: int64
# A    11
# B    13
# C    15
# D    20
# E    23
# F    26
# A     3
# B     4
# C     6
# D     8
# E     9
# F    10
# dtype: int64

# %%
#Create a Series containing the boiling points of the above solvents with the solvent names as the indices.
import pandas as pd
index = ('benzene', 'acetone', 'toluene', 'pentane', 'ether', 'ethanol', 'methanol')
table = pd.Series([80, 56, 111, 36, 35, 78, 65], index = index)
table['ethanol']
# Out:
# 78

# %%
#Create a DataFrame that contains both the boiling points and melting points with the solvent names as the indices.
index = ('benzene', 'acetone', 'toluene', 'pentane', 'ether', 'ethanol', 'methanol')
values = [80, 6], [56, -95], [111, -95], [36, -130], [35, -116], [78, -114], [65, -98]
tabledf = pd.DataFrame(values, columns = ['bp', 'mp'], index = index)
tabledf
# Out:
#            bp   mp
# benzene    80    6
# acetone    56  -95
# toluene   111  -95
# pentane    36 -130
# ether      35 -116
# ethanol    78 -114
# methanol   65  -98

# %%
tabledf.loc['benzene']
# Out:
# bp    80
# mp     6
# Name: benzene, dtype: int64

# %%
tabledf.iloc[3, 0]
# Out:
# 36

# %%
 
#Set the wavelengths as the index values.
bluedf.set_index('wavelength (nm)', inplace=True)
bluedf.to_csv('E:\\code\\blue1.csv')
print(bluedf.head())
# Out:
#       ,"nm,abs"
# 0  0,"400,0.09"
# 1  1,"401,0.09"
# 2  2,"402,0.09"
# 3   3,"403,0.1"
# 4   4,"404,0.1"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21608\853000126.py in ?()
#       1 #Import the attached file blue1.csv containing the absorption spectrum of Blue 1 food dye using pandas.
#       2 bluedf = pd.read_csv('E:\\code\\blue1.csv', delimiter = ';')
#       3 print(bluedf.head())
#       4 #Set the wavelengths as the index values.
# ----> 5 bluedf.set_index('wavelength (nm)', inplace=True)
#       6 bluedf.to_csv('E:\\code\\blue1.csv')
#       7 print(bluedf.head())
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# ...

# %%
bluedf = pd.read_csv('E:\\code\\blue1.csv', delimiter=';')

# Print column names to identify correct name for wavelength column
print("Columns in DataFrame:", bluedf.columns)

# Replace 'Wavelength (nm)' with whatever your column name actually is
bluedf.set_index('Wavelength (nm)', inplace=True)

print(bluedf.head())
# Out:
# Columns in DataFrame: Index([',"nm,abs"'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21608\3114814770.py in ?()
#       3 # Print column names to identify correct name for wavelength column
#       4 print("Columns in DataFrame:", bluedf.columns)
#       5
#       6 # Replace 'Wavelength (nm)' with whatever your column name actually is
# ----> 7 bluedf.set_index('Wavelength (nm)', inplace=True)
#       8
#       9 print(bluedf.head())
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
# ...

# %%
#Import the file kinetics.csv containing time series data 
import pandas as pd
df = pd.read_csv('E:\\code\\kinetics.csv')
df
# Out:
#     Unnamed: 0    [A](M)      time(s)
# 0            0  1.302199     0.000000
# 1            1  1.098668    20.408163
# 2            2  0.931701    40.816327
# 3            3  0.825958    61.224490
# 4            4  0.737428    81.632653
# 5            5  0.659194   102.040816
# 6            6  0.607217   122.448980
# 7            7  0.548590   142.857143
# 8            8  0.500425   163.265306
# 9            9  0.481235   183.673469
# 10          10  0.444763   204.081633
# 11          11  0.432573   224.489796
# 12          12  0.398956   244.897959
# 13          13  0.375308   265.306122
# 14          14  0.352901   285.714286
# 15          15  0.327420   306.122449
# 16          16  0.311975   326.530612
# 17          17  0.301059   346.938776
# 18          18  0.284085   367.346939
# 19          19  0.279747   387.755102
# 20          20  0.278564   408.163265
# 21          21  0.253688   428.571429
# 22          22  0.238900   448.979592
# 23          23  0.240955   469.387755
# ...

# %%
#Import the file kinetics.csv containing time series data 
import pandas as pd
import numpy as np
df = pd.read_csv('E:\\code\\kinetics.csv')
df.columns = df.columns.str.strip()
print(df.head())
# Out:
#    Unnamed: 0    [A](M)    time(s)
# 0           0  1.302199   0.000000
# 1           1  1.098668  20.408163
# 2           2  0.931701  40.816327
# 3           3  0.825958  61.224490
# 4           4  0.737428  81.632653

# %%
import pandas as pd
## using the 'head' function for displaying last items

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs').head()
print(kinetics_data)
# Out:
#             time(s)
# Abs
# 1.302199   0.000000
# 1.098668  20.408163
# 0.931701  40.816327
# 0.825958  61.224490
# 0.737428  81.632653

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
print(kinetics_data.head(8))
# Out:
#              time(s)
# Abs
# 1.302199    0.000000
# 1.098668   20.408163
# 0.931701   40.816327
# 0.825958   61.224490
# 0.737428   81.632653
# 0.659194  102.040816
# 0.607217  122.448980
# 0.548590  142.857143

# %%
## using the 'tail' function for displaying last items

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
print(kinetics_data.tail(8))
# Out:
#               time(s)
# Abs
# 0.155149   857.142857
# 0.136709   877.551020
# 0.145676   897.959184
# 0.131539   918.367347
# 0.136325   938.775510
# 0.132581   959.183674
# 0.139195   979.591837
# 0.122160  1000.000000

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs').tail()
print(kinetics_data)
# Out:
#               time(s)
# Abs
# 0.131539   918.367347
# 0.136325   938.775510
# 0.132581   959.183674
# 0.139195   979.591837
# 0.122160  1000.000000

# %%
## using the 'sample' function for displaying random selections ----- used when there is a bias in the data

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs').sample(5)
print(kinetics_data)
# Out:
#              time(s)
# Abs
# 0.136709  877.551020
# 0.145676  897.959184
# 0.500425  163.265306
# 0.240955  469.387755
# 0.177624  653.061224

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs').sample()
print(kinetics_data)
# Out:
#              time(s)
# Abs
# 0.253688  428.571429

# %%
## using the 'value_counts' function ----- gives frequency

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs').value_counts()
print(kinetics_data)
# Out:
# time(s)
# 0.000000       1
# 20.408163      1
# 40.816327      1
# 61.224490      1
# 81.632653      1
# 102.040816     1
# 122.448980     1
# 142.857143     1
# 163.265306     1
# 183.673469     1
# 204.081633     1
# 224.489796     1
# 244.897959     1
# 265.306122     1
# 285.714286     1
# 306.122449     1
# 326.530612     1
# 346.938776     1
# 367.346939     1
# 387.755102     1
# 408.163265     1
# 428.571429     1
# 448.979592     1
# 469.387755     1
# 489.795918     1
# 510.204082     1
# 530.612245     1
# 551.020408     1
# 571.428571     1
# 591.836735     1
# 612.244898     1
# 632.653061     1
# 653.061224     1
# 673.469388     1
# 693.877551     1
# 714.285714     1
# 734.693878     1
# 755.102041     1
# 775.510204     1
# 795.918367     1
# 816.326531     1
# 836.734694     1
# 857.142857     1
# 877.551020     1
# 897.959184     1
# 918.367347     1
# 938.775510     1
# 959.183674     1
# 979.591837     1
# 1000.000000    1
# Name: count, dtype: int64

# %%
## using the 'sort_vallues' function ----- gives sorted data
import pandas as pd

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
print(kinetics_data.sort_values(by='Abs',ascending=True).head(5))
# Out:
#               time(s)
# Abs
# 0.122160  1000.000000
# 0.131539   918.367347
# 0.132581   959.183674
# 0.136325   938.775510
# 0.136709   877.551020

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
kinetics_data.sort_values(by='Abs')
# Out:
#               time(s)
# Abs
# 0.122160  1000.000000
# 0.131539   918.367347
# 0.132581   959.183674
# 0.136325   938.775510
# 0.136709   877.551020
# 0.139195   979.591837
# 0.141220   795.918367
# 0.142958   816.326531
# 0.145676   897.959184
# 0.147815   775.510204
# 0.150236   836.734694
# 0.150481   755.102041
# 0.155149   857.142857
# 0.165135   714.285714
# 0.165978   734.693878
# 0.171859   693.877551
# 0.177624   653.061224
# 0.183165   632.653061
# 0.184039   673.469388
# 0.184420   612.244898
# 0.195166   591.836735
# 0.199857   551.020408
# 0.205558   571.428571
# 0.220761   530.612245
# 0.221159   510.204082
# 0.238900   448.979592
# 0.240955   469.387755
# 0.241087   489.795918
# 0.253688   428.571429
# 0.278564   408.163265
# 0.279747   387.755102
# 0.284085   367.346939
# 0.301059   346.938776
# 0.311975   326.530612
# 0.327420   306.122449
# 0.352901   285.714286
# 0.375308   265.306122
# 0.398956   244.897959
# 0.432573   224.489796
# 0.444763   204.081633
# ...

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
print(kinetics_data.sort_values(by='Abs',ascending=False))
# Out:
#               time(s)
# Abs
# 1.302199     0.000000
# 1.098668    20.408163
# 0.931701    40.816327
# 0.825958    61.224490
# 0.737428    81.632653
# 0.659194   102.040816
# 0.607217   122.448980
# 0.548590   142.857143
# 0.500425   163.265306
# 0.481235   183.673469
# 0.444763   204.081633
# 0.432573   224.489796
# 0.398956   244.897959
# 0.375308   265.306122
# 0.352901   285.714286
# 0.327420   306.122449
# 0.311975   326.530612
# 0.301059   346.938776
# 0.284085   367.346939
# 0.279747   387.755102
# 0.278564   408.163265
# 0.253688   428.571429
# 0.241087   489.795918
# 0.240955   469.387755
# 0.238900   448.979592
# 0.221159   510.204082
# 0.220761   530.612245
# 0.205558   571.428571
# 0.199857   551.020408
# 0.195166   591.836735
# 0.184420   612.244898
# 0.184039   673.469388
# 0.183165   632.653061
# 0.177624   653.061224
# 0.171859   693.877551
# 0.165978   734.693878
# 0.165135   714.285714
# 0.155149   857.142857
# 0.150481   755.102041
# 0.150236   836.734694
# ...

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
kinetics_data.sort_values(by='Abs').head(1)
# Out:
#          time(s)
# Abs
# 0.12216   1000.0

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
kinetics_data.sort_values(by='Abs',ascending=False).head(1)
# Out:
#           time(s)
# Abs
# 1.302199      0.0

# %% [markdown]
# ### Method Chaining

# %%
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
kinetics_data.sort_values(by='Abs',ascending=False).head(3).values[0]
# Out:
# array([0.])

# %%
## using the 'inplace' with 'sort_vallues' function ----- makes changes in the original database

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
kinetics_data.sort_values(by='Abs',inplace=True)

# %%
## using the 'sort_index' function ---- sorts the index in alphabetical order for different kinds of data

kinetics_data.sort_index(ascending=False)
# Out:
#               time(s)
# Abs
# 1.302199     0.000000
# 1.098668    20.408163
# 0.931701    40.816327
# 0.825958    61.224490
# 0.737428    81.632653
# 0.659194   102.040816
# 0.607217   122.448980
# 0.548590   142.857143
# 0.500425   163.265306
# 0.481235   183.673469
# 0.444763   204.081633
# 0.432573   224.489796
# 0.398956   244.897959
# 0.375308   265.306122
# 0.352901   285.714286
# 0.327420   306.122449
# 0.311975   326.530612
# 0.301059   346.938776
# 0.284085   367.346939
# 0.279747   387.755102
# 0.278564   408.163265
# 0.253688   428.571429
# 0.241087   489.795918
# 0.240955   469.387755
# 0.238900   448.979592
# 0.221159   510.204082
# 0.220761   530.612245
# 0.205558   571.428571
# 0.199857   551.020408
# 0.195166   591.836735
# 0.184420   612.244898
# 0.184039   673.469388
# 0.183165   632.653061
# 0.177624   653.061224
# 0.171859   693.877551
# 0.165978   734.693878
# 0.165135   714.285714
# 0.155149   857.142857
# 0.150481   755.102041
# 0.150236   836.734694
# ...

# %% [markdown]
# ### Series Mathematical Functions

# %%
### 'count' ---- will count the rows, except the missing values, 'size' counts the missing values
import pandas as pd

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
kinetics_data.count()
# Out:
# time(s)    50
# dtype: int64

# %%
### sum 

kinetics_data.sum()
# Out:
# time(s)    25000.0
# dtype: float64

# %%
### product 

kinetics_data.product()
# Out:
# time(s)    0.0
# dtype: float64

# %%
## mean

kinetics_data.mean()
# Out:
# time(s)    500.0
# dtype: float64

# %%
## median

kinetics_data.median()
# Out:
# time(s)    500.0
# dtype: float64

# %%
## mode
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
print(kinetics_data.std())
# Out:
# time(s)    297.497546
# dtype: float64

# %%
## min -- max
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
print(kinetics_data.max())
# Out:
# time(s)    1000.0
# dtype: float64

# %%
## describe

kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
print(kinetics_data.describe())
# Out:
#            time(s)
# count    50.000000
# mean    500.000000
# std     297.497546
# min       0.000000
# 25%     250.000000
# 50%     500.000000
# 75%     750.000000
# max    1000.000000

# %% [markdown]
# ### Series Indexing

# %%
## Integer indexing

Ele_index = ('Li', 'Be', 'C', 'O', 'F', 'Ne' )
mass_1 = pd.Series([3, 4, 6, 8, 9, 10], index = Ele_index)
print(mass_1)
# Out:
# Li     3
# Be     4
# C      6
# O      8
# F      9
# Ne    10
# dtype: int64

# %%
mass_1 = pd.Series([3, 4, 6, 8, 9, 10])
mass_1[0]
# Out:
# np.int64(3)

# %%
mass_1 = pd.Series([3, 4, 6, 8, 9, 10])
mass_1[4]

###  negative indexing doesn't work index are numbers, but when index is string it wrks
# Out:
# np.int64(9)

# %% [markdown]
# ### Slicing

# %%
kinetics_data[5:16]
# Out:
#              time(s)
# Abs
# 0.659194  102.040816
# 0.607217  122.448980
# 0.548590  142.857143
# 0.500425  163.265306
# 0.481235  183.673469
# 0.444763  204.081633
# 0.432573  224.489796
# 0.398956  244.897959
# 0.375308  265.306122
# 0.352901  285.714286
# 0.327420  306.122449

# %%
## negative sicing

kinetics_data[-5:]
# Out:
#               time(s)
# Abs
# 0.131539   918.367347
# 0.136325   938.775510
# 0.132581   959.183674
# 0.139195   979.591837
# 0.122160  1000.000000

# %%
### Indexing with labels--- suppose the movies of an actor data [we can write the label name /movie name and get the corresponding column value]
### Fancy indexing

# %% [markdown]
# ### Editing the series

# %%
## using slicing
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
kinetics_data[3:8]=40
kinetics_data
print(max(kinetics_data))
# Out:
# time(s)

# %% [markdown]
# ## Seires with Python Functionality

# %%
## len / type / dir / sorted /max /min

import pandas as pd
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')

print(len(kinetics_data))
print(type(kinetics_data))
print(min(kinetics_data))
print(max(kinetics_data))
# Out:
# 50
# <class 'pandas.DataFrame'>
# time(s)
# time(s)

# %%
## type conversion

list(kinetics_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 ## type conversion
#       2
# ----> 3 list(kinetics_data)
#
# NameError: name 'kinetics_data' is not defined

# %%
## membership operator "in"  ---- it works on index not on the 'values'

import pandas as pd
kinetics_data = pd.read_csv("E:\\code\\kinetics.csv", index_col='Abs')
20.4 in kinetics_data
# Out:
# False

# %%
## looping  ----- this will print all the values not the index

for i in kinetics_data:
    print(i)
# Out:
# time(s)

# %%
## looping  ----- this will print all the values not the index
## but following can print the index

for i in kinetics_data.index:
    print(i)
# Out:
# 1.302198893
# 1.098668035
# 0.93170113
# 0.825957843
# 0.737427905
# 0.659193643
# 0.607217346
# 0.548590023
# 0.50042468
# 0.481235047
# 0.444763279
# 0.432572738
# 0.398955834
# 0.375308477
# 0.352901325
# 0.327420424
# 0.311975289
# 0.301058875
# 0.284084932
# 0.279746582
# 0.278564308
# 0.253688397
# 0.238899696
# 0.240955233
# 0.241086985
# 0.221159275
# 0.22076144
# 0.199857282
# 0.205558334
# 0.195165642
# 0.18441982
# 0.183165358
# 0.177624319
# 0.184039393
# 0.171858565
# 0.165135368
# 0.1659782
# 0.150480865
# 0.14781465
# 0.14122002
# 0.142958175
# 0.150236006
# 0.155149158
# 0.136709016
# 0.145676223
# 0.131538736
# 0.13632509
# 0.132581284
# 0.139194875
# 0.122160472

# %%
## airthithmetic operators

4 + kinetics_data
# Out:
#               time(s)
# Abs
# 1.302199     4.000000
# 1.098668    24.408163
# 0.931701    44.816327
# 0.825958    65.224490
# 0.737428    85.632653
# 0.659194   106.040816
# 0.607217   126.448980
# 0.548590   146.857143
# 0.500425   167.265306
# 0.481235   187.673469
# 0.444763   208.081633
# 0.432573   228.489796
# 0.398956   248.897959
# 0.375308   269.306122
# 0.352901   289.714286
# 0.327420   310.122449
# 0.311975   330.530612
# 0.301059   350.938776
# 0.284085   371.346939
# 0.279747   391.755102
# 0.278564   412.163265
# 0.253688   432.571429
# 0.238900   452.979592
# 0.240955   473.387755
# 0.241087   493.795918
# 0.221159   514.204082
# 0.220761   534.612245
# 0.199857   555.020408
# 0.205558   575.428571
# 0.195166   595.836735
# 0.184420   616.244898
# 0.183165   636.653061
# 0.177624   657.061224
# 0.184039   677.469388
# 0.171859   697.877551
# 0.165135   718.285714
# 0.165978   738.693878
# 0.150481   759.102041
# 0.147815   779.510204
# 0.141220   799.918367
# ...

# %%
1000 - kinetics_data
# Out:
#               time(s)
# Abs
# 1.302199  1000.000000
# 1.098668   979.591837
# 0.931701   959.183673
# 0.825958   938.775510
# 0.737428   918.367347
# 0.659194   897.959184
# 0.607217   877.551020
# 0.548590   857.142857
# 0.500425   836.734694
# 0.481235   816.326531
# 0.444763   795.918367
# 0.432573   775.510204
# 0.398956   755.102041
# 0.375308   734.693878
# 0.352901   714.285714
# 0.327420   693.877551
# 0.311975   673.469388
# 0.301059   653.061224
# 0.284085   632.653061
# 0.279747   612.244898
# 0.278564   591.836735
# 0.253688   571.428571
# 0.238900   551.020408
# 0.240955   530.612245
# 0.241087   510.204082
# 0.221159   489.795918
# 0.220761   469.387755
# 0.199857   448.979592
# 0.205558   428.571429
# 0.195166   408.163265
# 0.184420   387.755102
# 0.183165   367.346939
# 0.177624   346.938776
# 0.184039   326.530612
# 0.171859   306.122449
# 0.165135   285.714286
# 0.165978   265.306122
# 0.150481   244.897959
# 0.147815   224.489796
# 0.141220   204.081633
# ...

# %%
###(broadcasting example, the operation is applied to the whole data)

4 ** kinetics_data
# Out:
#                 time(s)
# Abs
# 1.302199   1.000000e+00
# 1.098668   1.936148e+12
# 0.931701   3.748670e+24
# 0.825958   7.257981e+36
# 0.737428   1.405253e+49
# 0.659194   2.720777e+61
# 0.607217   5.267828e+73
# 0.548590   1.019930e+86
# 0.500425   1.974735e+98
# 0.481235  3.823379e+110
# 0.444763  7.402629e+122
# 0.432573  1.433259e+135
# 0.398956  2.775001e+147
# 0.375308  5.372813e+159
# 0.352901  1.040256e+172
# 0.327420  2.014091e+184
# 0.311975  3.899577e+196
# 0.301059  7.550160e+208
# 0.284085  1.461823e+221
# 0.279747  2.830306e+233
# 0.278564  5.479892e+245
# 0.253688  1.060988e+258
# 0.238900  2.054230e+270
# 0.240955  3.977295e+282
# 0.241087  7.700632e+294
# 0.221159  1.490956e+307
# 0.220761            inf
# 0.199857            inf
# 0.205558            inf
# 0.195166            inf
# 0.184420            inf
# 0.183165            inf
# 0.177624            inf
# 0.184039            inf
# 0.171859            inf
# 0.165135            inf
# 0.165978            inf
# ...

# %%
## Relational operators 

kinetics_data >= 500
# Out:
#           time(s)
# Abs
# 1.302199    False
# 1.098668    False
# 0.931701    False
# 0.825958    False
# 0.737428    False
# 0.659194    False
# 0.607217    False
# 0.548590    False
# 0.500425    False
# 0.481235    False
# 0.444763    False
# 0.432573    False
# 0.398956    False
# 0.375308    False
# 0.352901    False
# 0.327420    False
# 0.311975    False
# 0.301059    False
# 0.284085    False
# 0.279747    False
# 0.278564    False
# 0.253688    False
# 0.238900    False
# 0.240955    False
# 0.241087    False
# 0.221159     True
# 0.220761     True
# 0.199857     True
# 0.205558     True
# 0.195166     True
# 0.184420     True
# 0.183165     True
# 0.177624     True
# 0.184039     True
# 0.171859     True
# 0.165135     True
# 0.165978     True
# 0.150481     True
# 0.147815     True
# 0.141220     True
# 0.142958     True
# 0.150236     True
# 0.155149     True
# 0.136709     True
# 0.145676     True
# 0.131539     True
# 0.136325     True
# 0.132581     True
# ...

# %%
## Relational operators ---- Boolean indexing on series

kinetics_data[kinetics_data >= 100]
# Out:
#               time(s)
# Abs
# 1.302199          NaN
# 1.098668          NaN
# 0.931701          NaN
# 0.825958          NaN
# 0.737428          NaN
# 0.659194   102.040816
# 0.607217   122.448980
# 0.548590   142.857143
# 0.500425   163.265306
# 0.481235   183.673469
# 0.444763   204.081633
# 0.432573   224.489796
# 0.398956   244.897959
# 0.375308   265.306122
# 0.352901   285.714286
# 0.327420   306.122449
# 0.311975   326.530612
# 0.301059   346.938776
# 0.284085   367.346939
# 0.279747   387.755102
# 0.278564   408.163265
# 0.253688   428.571429
# 0.238900   448.979592
# 0.240955   469.387755
# 0.241087   489.795918
# 0.221159   510.204082
# 0.220761   530.612245
# 0.199857   551.020408
# 0.205558   571.428571
# 0.195166   591.836735
# 0.184420   612.244898
# 0.183165   632.653061
# 0.177624   653.061224
# 0.184039   673.469388
# 0.171859   693.877551
# 0.165135   714.285714
# 0.165978   734.693878
# 0.150481   755.102041
# 0.147815   775.510204
# 0.141220   795.918367
# ...

# %%
kinetics_data == 100
# Out:
#           time(s)
# Abs
# 1.302199    False
# 1.098668    False
# 0.931701    False
# 0.825958    False
# 0.737428    False
# 0.659194    False
# 0.607217    False
# 0.548590    False
# 0.500425    False
# 0.481235    False
# 0.444763    False
# 0.432573    False
# 0.398956    False
# 0.375308    False
# 0.352901    False
# 0.327420    False
# 0.311975    False
# 0.301059    False
# 0.284085    False
# 0.279747    False
# 0.278564    False
# 0.253688    False
# 0.238900    False
# 0.240955    False
# 0.241087    False
# 0.221159    False
# 0.220761    False
# 0.199857    False
# 0.205558    False
# 0.195166    False
# 0.184420    False
# 0.183165    False
# 0.177624    False
# 0.184039    False
# 0.171859    False
# 0.165135    False
# 0.165978    False
# 0.150481    False
# 0.147815    False
# 0.141220    False
# 0.142958    False
# 0.150236    False
# 0.155149    False
# 0.136709    False
# 0.145676    False
# 0.131539    False
# 0.136325    False
# 0.132581    False
# ...

# %%
subs = pd.read_csv("E:\\code\\subs.csv")
subs>200
# Out:
#      Subscribers gained
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 360                True
# 361                True
# 362               False
# 363               False
# 364               False
#
# [365 rows x 1 columns]

# %%
subs[subs>200].size
# Out:
# 365

# %%
### finding no of actors who did more than 20 movies in bollywood dataset

num_movies = movies.value_counts()
num_movies>20

# %%
## import matplotlib.pyplot as plt

kinetics_data.plot()
# Out:
# <Axes: xlabel='Abs'>

# %%
subs.plot()
# Out:
# <Axes: >

# %%
subs.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Subscribers gained'>
