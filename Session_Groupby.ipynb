# %%
import pandas as pd
import numpy as np

PCT=pd.read_csv('clinical_trials.csv')
PCT.head()
# Out:
#    subject_id patient_id                   trial_name   trial_id  \
# 0  SUBJ200000   PT100346       ONCO-217 (Lung Cancer)  TRIAL-001
# 1  SUBJ200001   PT100311  RESPIRA-3 (Asthma Biologic)  TRIAL-005
# 2  SUBJ200002   PT101154   GLYCOX-4 (Type 2 Diabetes)  TRIAL-003
# 3  SUBJ200003   PT101061       ONCO-217 (Lung Cancer)  TRIAL-001
# 4  SUBJ200004   PT100094     CARDIA-9 (Heart Failure)  TRIAL-002
#
#            study_arm  dosage_mg enrollment_date  follow_up_weeks  \
# 0          Treatment      200.0      2023-04-12               24
# 1            Placebo       50.0      2024-03-28                4
# 2          Treatment      100.0      2025-01-07                8
# 3          Treatment      150.0      2023-02-05                8
# 4  Active Comparator      200.0      2023-11-18               12
#
#    responded_to_treatment             adverse_event  completed_trial
# 0                   False                       NaN             True
# ...

# %%
category=PCT.groupby('study_arm')

# %%
## applying builtin aggregation functions on groupby objects

category.sum()
# Out:
#                                                           subject_id  \
# study_arm
# Active Comparator  SUBJ200004SUBJ200008SUBJ200010SUBJ200024SUBJ20...
# Placebo            SUBJ200001SUBJ200005SUBJ200009SUBJ200012SUBJ20...
# Treatment          SUBJ200000SUBJ200002SUBJ200003SUBJ200006SUBJ20...
#
#                                                           patient_id  \
# study_arm
# Active Comparator  PT100094PT100294PT100107PT100189PT100640PT1001...
# Placebo            PT100311PT100916PT101035PT100857PT101028PT1010...
# Treatment          PT100346PT101154PT101061PT100274PT101021PT1000...
#
#                                                           trial_name  \
# study_arm
# Active Comparator  CARDIA-9 (Heart Failure)NEURA-12 (Alzheimer's)...
# Placebo            RESPIRA-3 (Asthma Biologic)CARDIA-9 (Heart Fai...
# Treatment          ONCO-217 (Lung Cancer)GLYCOX-4 (Type 2 Diabete...
#
#                                                             trial_id  \
# study_arm
# ...

# %%
category.min()
# Out:
#                    subject_id patient_id                trial_name   trial_id  \
# study_arm
# Active Comparator  SUBJ200004   PT100007  CARDIA-9 (Heart Failure)  TRIAL-001
# Placebo            SUBJ200001   PT100000  CARDIA-9 (Heart Failure)  TRIAL-001
# Treatment          SUBJ200000   PT100008  CARDIA-9 (Heart Failure)  TRIAL-001
#
#                    dosage_mg enrollment_date  follow_up_weeks  \
# study_arm
# Active Comparator       50.0      2023-01-01                4
# Placebo                 50.0      2023-01-14                4
# Treatment               50.0      2023-01-05                4
#
#                    responded_to_treatment    adverse_event  completed_trial
# study_arm
# Active Comparator                   False  Mild - Headache            False
# Placebo                             False  Mild - Headache            False
# Treatment                           False  Mild - Headache            False

# %%
category['dosage_mg'].mean()
# Out:
# study_arm
# Active Comparator    117.829457
# Placebo              119.306931
# Treatment            118.309859
# Name: dosage_mg, dtype: float64

# %%
PCT.groupby('study_arm').sum()['adverse_event']
# Out:
# study_arm
# Active Comparator    Moderate - FatigueModerate - FatigueMild - Nau...
# Placebo              Severe - HospitalizationMild - HeadacheModerat...
# Treatment            Moderate - FatigueMild - HeadacheModerate - Ra...
# Name: adverse_event, dtype: str

# %%
### study arms with  with grouped with adverse events

PCT.groupby('study_arm')['adverse_event'].value_counts()
# Out:
# study_arm          adverse_event
# Active Comparator  Moderate - Fatigue          21
#                    Mild - Nausea               16
#                    Mild - Headache             15
#                    Moderate - Rash             13
#                    Severe - Hospitalization     2
# Placebo            Moderate - Fatigue          29
#                    Mild - Headache             28
#                    Mild - Nausea               24
#                    Moderate - Rash             20
#                    Severe - Hospitalization    13
# Treatment          Mild - Nausea               30
#                    Moderate - Fatigue          29
#                    Mild - Headache             24
#                    Moderate - Rash             13
#                    Severe - Hospitalization     5
# Name: count, dtype: int64

# %%
PCT.groupby('study_arm')['follow_up_weeks'].value_counts()
# Out:
# study_arm          follow_up_weeks
# Active Comparator  4                  30
#                    52                 30
#                    12                 29
#                    8                  26
#                    24                 24
# Placebo            12                 50
#                    52                 46
#                    4                  44
#                    8                  41
#                    24                 35
# Treatment          8                  54
#                    52                 54
#                    12                 51
#                    24                 44
#                    4                  42
# Name: count, dtype: int64

# %%
PCT.groupby('study_arm')['follow_up_weeks'].mean()
# Out:
# study_arm
# Active Comparator    20.230216
# Placebo              20.074074
# Treatment            20.718367
# Name: follow_up_weeks, dtype: float64

# %%
PCT.groupby('study_arm')['dosage_mg'].mean()
# Out:
# study_arm
# Active Comparator    117.829457
# Placebo              119.306931
# Treatment            118.309859
# Name: dosage_mg, dtype: float64

# %%
PCT.groupby('study_arm')['dosage_mg'].value_counts()
# Out:
# study_arm          dosage_mg
# Active Comparator  150.0        41
#                    100.0        39
#                    50.0         31
#                    200.0        18
# Placebo            100.0        73
#                    150.0        48
#                    50.0         44
#                    200.0        37
# Treatment          100.0        89
#                    150.0        59
#                    50.0         37
#                    200.0        28
# Name: count, dtype: int64

# %%
PCT.groupby('study_arm')['dosage_mg'].sum().sort_values()
# Out:
# study_arm
# Active Comparator    15200.0
# Placebo              24100.0
# Treatment            25200.0
# Name: dosage_mg, dtype: float64

# %%
PCT.groupby('adverse_event')['dosage_mg'].sum().sort_values()
# Out:
# adverse_event
# Severe - Hospitalization    1600.0
# Moderate - Rash             4750.0
# Mild - Nausea               7150.0
# Mild - Headache             7750.0
# Moderate - Fatigue          8650.0
# Name: dosage_mg, dtype: float64

# %%
PCT.groupby('adverse_event')['dosage_mg'].value_counts()
# Out:
# adverse_event             dosage_mg
# Mild - Headache           100.0        19
#                           50.0         16
#                           150.0        15
#                           200.0        14
# Mild - Nausea             100.0        27
#                           150.0        16
#                           50.0         13
#                           200.0         7
# Moderate - Fatigue        100.0        30
#                           150.0        18
#                           50.0         15
#                           200.0        11
# Moderate - Rash           100.0        16
#                           150.0        11
#                           50.0         10
#                           200.0         5
# Severe - Hospitalization  100.0         8
#                           50.0          6
#                           150.0         2
#                           200.0         1
# Name: count, dtype: int64

# %%
PCT.groupby('adverse_event')['dosage_mg'].value_counts().sort_values(ascending=False)
# Out:
# adverse_event             dosage_mg
# Moderate - Fatigue        100.0        30
# Mild - Nausea             100.0        27
# Mild - Headache           100.0        19
# Moderate - Fatigue        150.0        18
# Moderate - Rash           100.0        16
# Mild - Nausea             150.0        16
# Mild - Headache           50.0         16
#                           150.0        15
# Moderate - Fatigue        50.0         15
# Mild - Headache           200.0        14
# Mild - Nausea             50.0         13
# Moderate - Fatigue        200.0        11
# Moderate - Rash           150.0        11
#                           50.0         10
# Severe - Hospitalization  100.0         8
# Mild - Nausea             200.0         7
# Severe - Hospitalization  50.0          6
# Moderate - Rash           200.0         5
# Severe - Hospitalization  150.0         2
#                           200.0         1
# Name: count, dtype: int64

# %%
PCT.groupby('subject_id')['follow_up_weeks'].sum()
# Out:
# subject_id
# SUBJ200000    24
# SUBJ200001     4
# SUBJ200002     8
# SUBJ200003     8
# SUBJ200004    12
#               ..
# SUBJ200595    24
# SUBJ200596    24
# SUBJ200597    12
# SUBJ200598    52
# SUBJ200599    52
# Name: follow_up_weeks, Length: 600, dtype: int64

# %%
## subject with higest follow up

PCT.groupby('subject_id')['follow_up_weeks'].sum().sort_values(ascending=False).head(1)
# Out:
# subject_id
# SUBJ200599    52
# Name: follow_up_weeks, dtype: int64

# %%
PCT.groupby('study_arm')['follow_up_weeks'].max()
# Out:
# study_arm
# Active Comparator    52
# Placebo              52
# Treatment            52
# Name: follow_up_weeks, dtype: int64

# %%
PCT.groupby('subject_id')['trial_name'].value_counts()
# Out:
# subject_id  trial_name
# SUBJ200000  ONCO-217 (Lung Cancer)         1
# SUBJ200001  RESPIRA-3 (Asthma Biologic)    1
# SUBJ200002  GLYCOX-4 (Type 2 Diabetes)     1
# SUBJ200003  ONCO-217 (Lung Cancer)         1
# SUBJ200004  CARDIA-9 (Heart Failure)       1
#                                           ..
# SUBJ200595  CARDIA-9 (Heart Failure)       1
# SUBJ200596  CARDIA-9 (Heart Failure)       1
# SUBJ200597  ONCO-217 (Lung Cancer)         1
# SUBJ200598  NEURA-12 (Alzheimer's)         1
# SUBJ200599  ONCO-217 (Lung Cancer)         1
# Name: count, Length: 600, dtype: int64

# %%
PCT['completed_trial'].value_counts()
# Out:
# completed_trial
# True     512
# False     88
# Name: count, dtype: int64

# %%
PCT.groupby('subject_id')['completed_trial'].count().head(20)
# Out:
# subject_id
# SUBJ200000    1
# SUBJ200001    1
# SUBJ200002    1
# SUBJ200003    1
# SUBJ200004    1
# SUBJ200005    1
# SUBJ200006    1
# SUBJ200007    1
# SUBJ200008    1
# SUBJ200009    1
# SUBJ200010    1
# SUBJ200011    1
# SUBJ200012    1
# SUBJ200013    1
# SUBJ200014    1
# SUBJ200015    1
# SUBJ200016    1
# SUBJ200017    1
# SUBJ200018    1
# SUBJ200019    1
# Name: completed_trial, dtype: int64

# %% [markdown]
# ###  Groupby methods and attributes

# %%
## number of groups formed----------> .unique() can also work the same

len(PCT.groupby('study_arm'))
# Out:
# 3

# %%
len(PCT.groupby('adverse_event'))
# Out:
# 5

# %%
## number of items in each adverse event group -----> done by .size() and value counts()
## size does the alphabetical order of index

PCT.groupby('adverse_event').size()
# Out:
# adverse_event
# Mild - Headache             67
# Mild - Nausea               70
# Moderate - Fatigue          79
# Moderate - Rash             46
# Severe - Hospitalization    20
# dtype: int64

# %%
PCT['adverse_event'].value_counts()
# Out:
# adverse_event
# Moderate - Fatigue          79
# Mild - Nausea               70
# Mild - Headache             67
# Moderate - Rash             46
# Severe - Hospitalization    20
# Name: count, dtype: int64

# %%
### gives the first pateint under the each adverse event group

PCT.groupby('adverse_event').first()
# Out:
#                           subject_id patient_id                   trial_name  \
# adverse_event
# Mild - Headache           SUBJ200003   PT101061       ONCO-217 (Lung Cancer)
# Mild - Nausea             SUBJ200022   PT100715       NEURA-12 (Alzheimer's)
# Moderate - Fatigue        SUBJ200002   PT101154   GLYCOX-4 (Type 2 Diabetes)
# Moderate - Rash           SUBJ200011   PT100008       NEURA-12 (Alzheimer's)
# Severe - Hospitalization  SUBJ200001   PT100311  RESPIRA-3 (Asthma Biologic)
#
#                            trial_id  study_arm  dosage_mg enrollment_date  \
# adverse_event
# Mild - Headache           TRIAL-001  Treatment      150.0      2023-02-05
# Mild - Nausea             TRIAL-004  Treatment      100.0      2025-04-19
# Moderate - Fatigue        TRIAL-003  Treatment      100.0      2025-01-07
# Moderate - Rash           TRIAL-004  Treatment      150.0      2023-10-15
# Severe - Hospitalization  TRIAL-005    Placebo       50.0      2024-03-28
#
# ...

# %%
PCT.groupby('adverse_event').last()
# Out:
#                           subject_id patient_id                   trial_name  \
# adverse_event
# Mild - Headache           SUBJ200597   PT100169       ONCO-217 (Lung Cancer)
# Mild - Nausea             SUBJ200565   PT100039  RESPIRA-3 (Asthma Biologic)
# Moderate - Fatigue        SUBJ200599   PT100010       ONCO-217 (Lung Cancer)
# Moderate - Rash           SUBJ200552   PT100366       NEURA-12 (Alzheimer's)
# Severe - Hospitalization  SUBJ200590   PT100055  RESPIRA-3 (Asthma Biologic)
#
#                            trial_id          study_arm  dosage_mg  \
# adverse_event
# Mild - Headache           TRIAL-001            Placebo       50.0
# Mild - Nausea             TRIAL-005            Placebo       50.0
# Moderate - Fatigue        TRIAL-001            Placebo       50.0
# Moderate - Rash           TRIAL-004  Active Comparator      200.0
# Severe - Hospitalization  TRIAL-005            Placebo      150.0
#
#                          enrollment_date  follow_up_weeks  \
# ...

# %%
PCT.groupby('study_arm').first()
# Out:
#                    subject_id patient_id                   trial_name  \
# study_arm
# Active Comparator  SUBJ200004   PT100094     CARDIA-9 (Heart Failure)
# Placebo            SUBJ200001   PT100311  RESPIRA-3 (Asthma Biologic)
# Treatment          SUBJ200000   PT100346       ONCO-217 (Lung Cancer)
#
#                     trial_id  dosage_mg enrollment_date  follow_up_weeks  \
# study_arm
# Active Comparator  TRIAL-002      200.0      2023-11-18               12
# Placebo            TRIAL-005       50.0      2024-03-28                4
# Treatment          TRIAL-001      200.0      2023-04-12               24
#
#                    responded_to_treatment             adverse_event  \
# study_arm
# Active Comparator                    True        Moderate - Fatigue
# Placebo                             False  Severe - Hospitalization
# Treatment                           False        Moderate - Fatigue
#
#                    completed_trial
# study_arm
# ...

# %%
PCT.groupby('study_arm').last()
# Out:
#                    subject_id patient_id                trial_name   trial_id  \
# study_arm
# Active Comparator  SUBJ200596   PT100198  CARDIA-9 (Heart Failure)  TRIAL-002
# Placebo            SUBJ200599   PT100010    ONCO-217 (Lung Cancer)  TRIAL-001
# Treatment          SUBJ200595   PT100023  CARDIA-9 (Heart Failure)  TRIAL-002
#
#                    dosage_mg enrollment_date  follow_up_weeks  \
# study_arm
# Active Comparator      150.0      2023-04-16               24
# Placebo                 50.0      2024-04-20               52
# Treatment              100.0      2025-02-11               24
#
#                    responded_to_treatment       adverse_event  completed_trial
# study_arm
# Active Comparator                    True  Moderate - Fatigue             True
# Placebo                             False  Moderate - Fatigue             True
# Treatment                           False  Moderate - Fatigue            False

# %%
PCT.groupby('adverse_event').nth(2)
# Out:
#     subject_id patient_id                   trial_name   trial_id  \
# 17  SUBJ200017   PT100811  RESPIRA-3 (Asthma Biologic)  TRIAL-005
# 21  SUBJ200021   PT100799       NEURA-12 (Alzheimer's)  TRIAL-004
# 36  SUBJ200036   PT100034     CARDIA-9 (Heart Failure)  TRIAL-002
# 40  SUBJ200040   PT100460       NEURA-12 (Alzheimer's)  TRIAL-004
# 42  SUBJ200042   PT100026       ONCO-217 (Lung Cancer)  TRIAL-001
#
#             study_arm  dosage_mg enrollment_date  follow_up_weeks  \
# 17          Treatment       50.0      2023-04-11                4
# 21          Treatment      100.0      2023-08-31               12
# 36            Placebo      150.0      2024-09-08               24
# 40          Treatment      100.0      2023-08-07               24
# 42  Active Comparator       50.0      2024-10-02                8
#
#     responded_to_treatment             adverse_event  completed_trial
# 17                   False           Mild - Headache            False
# ...

# %%
PCT.groupby('study_arm').nth(5)
# Out:
#     subject_id patient_id                   trial_name   trial_id  \
# 11  SUBJ200011   PT100008       NEURA-12 (Alzheimer's)  TRIAL-004
# 16  SUBJ200016   PT101048       NEURA-12 (Alzheimer's)  TRIAL-004
# 35  SUBJ200035   PT100116  RESPIRA-3 (Asthma Biologic)  TRIAL-005
#
#             study_arm  dosage_mg enrollment_date  follow_up_weeks  \
# 11          Treatment      150.0      2023-10-15                8
# 16            Placebo      100.0      2025-03-25               24
# 35  Active Comparator      150.0      2024-03-22                4
#
#     responded_to_treatment    adverse_event  completed_trial
# 11                   False  Moderate - Rash             True
# 16                   False              NaN             True
# 35                    True    Mild - Nausea             True

# %%
### Get group function

A_E=PCT.groupby('study_arm')

A_E.get_group('Treatment')

###  can also be done by--> PCT[PCT[study_arm]=='Treatment']
# Out:
#      subject_id patient_id                   trial_name   trial_id  study_arm  \
# 0    SUBJ200000   PT100346       ONCO-217 (Lung Cancer)  TRIAL-001  Treatment
# 2    SUBJ200002   PT101154   GLYCOX-4 (Type 2 Diabetes)  TRIAL-003  Treatment
# 3    SUBJ200003   PT101061       ONCO-217 (Lung Cancer)  TRIAL-001  Treatment
# 6    SUBJ200006   PT100274       ONCO-217 (Lung Cancer)  TRIAL-001  Treatment
# 7    SUBJ200007   PT101021       ONCO-217 (Lung Cancer)  TRIAL-001  Treatment
# ..          ...        ...                          ...        ...        ...
# 587  SUBJ200587   PT100175       ONCO-217 (Lung Cancer)  TRIAL-001  Treatment
# 589  SUBJ200589   PT101166   GLYCOX-4 (Type 2 Diabetes)  TRIAL-003  Treatment
# 593  SUBJ200593   PT100176  RESPIRA-3 (Asthma Biologic)  TRIAL-005  Treatment
# 594  SUBJ200594   PT100697       ONCO-217 (Lung Cancer)  TRIAL-001  Treatment
# 595  SUBJ200595   PT100023     CARDIA-9 (Heart Failure)  TRIAL-002  Treatment
#
# ...

# %%
A_E.describe()
# Out:
#                   dosage_mg                                                    \
#                       count        mean        std   min    25%    50%    75%
# study_arm
# Active Comparator     129.0  117.829457  49.921207  50.0  100.0  100.0  150.0
# Placebo               202.0  119.306931  51.092686  50.0  100.0  100.0  150.0
# Treatment             213.0  118.309859  45.999977  50.0  100.0  100.0  150.0
#
#                          follow_up_weeks                                  \
#                      max           count       mean        std  min  25%
# study_arm
# Active Comparator  200.0           139.0  20.230216  17.932368  4.0  8.0
# Placebo            200.0           216.0  20.074074  17.788266  4.0  8.0
# Treatment          200.0           245.0  20.718367  17.841006  4.0  8.0
#
#
#                     50%   75%   max
# study_arm
# Active Comparator  12.0  24.0  52.0
# Placebo            12.0  24.0  52.0
# Treatment          12.0  24.0  52.0

# %%
PCT.groupby('adverse_event').describe()
# Out:
#                          dosage_mg                                             \
#                              count        mean        std   min    25%    50%
# adverse_event
# Mild - Headache               64.0  121.093750  54.775652  50.0   87.5  100.0
# Mild - Nausea                 63.0  113.492063  45.971896  50.0  100.0  100.0
# Moderate - Fatigue            74.0  116.891892  48.453499  50.0  100.0  100.0
# Moderate - Rash               42.0  113.095238  48.211328  50.0  100.0  100.0
# Severe - Hospitalization      17.0   94.117647  42.874646  50.0   50.0  100.0
#
#                                        follow_up_weeks                        \
#                             75%    max           count       mean        std
# adverse_event
# Mild - Headache           150.0  200.0            67.0  18.567164  17.707406
# Mild - Nausea             150.0  200.0            70.0  21.542857  18.998616
# Moderate - Fatigue        150.0  200.0            79.0  20.658228  18.346303
# ...

# %%
PCT.groupby('adverse_event').sample()
# Out:
#      subject_id patient_id                  trial_name   trial_id  study_arm  \
# 454  SUBJ200454   PT100706  GLYCOX-4 (Type 2 Diabetes)  TRIAL-003    Placebo
# 487  SUBJ200487   PT100879  GLYCOX-4 (Type 2 Diabetes)  TRIAL-003  Treatment
# 21   SUBJ200021   PT100799      NEURA-12 (Alzheimer's)  TRIAL-004  Treatment
# 12   SUBJ200012   PT100857      ONCO-217 (Lung Cancer)  TRIAL-001    Placebo
# 125  SUBJ200125   PT100045    CARDIA-9 (Heart Failure)  TRIAL-002    Placebo
#
#      dosage_mg enrollment_date  follow_up_weeks  responded_to_treatment  \
# 454       50.0      2024-02-19               24                    True
# 487      100.0      2025-03-15               52                    True
# 21       100.0      2023-08-31               12                   False
# 12       200.0      2024-01-02                8                   False
# 125       50.0      2023-02-04               24                   False
#
#                 adverse_event  completed_trial
# ...

# %%
A_E.sample()
# Out:
#      subject_id patient_id                  trial_name   trial_id  \
# 219  SUBJ200219   PT100419  GLYCOX-4 (Type 2 Diabetes)  TRIAL-003
# 561  SUBJ200561   PT100143      NEURA-12 (Alzheimer's)  TRIAL-004
# 594  SUBJ200594   PT100697      ONCO-217 (Lung Cancer)  TRIAL-001
#
#              study_arm  dosage_mg enrollment_date  follow_up_weeks  \
# 219  Active Comparator      100.0      2024-10-20               12
# 561            Placebo      100.0      2024-04-15               52
# 594          Treatment      200.0      2023-08-03               52
#
#      responded_to_treatment adverse_event  completed_trial
# 219                    True           NaN             True
# 561                    True           NaN            False
# 594                   False           NaN            False

# %%
A_E.sample(2, replace=True)
# Out:
#      subject_id patient_id                trial_name   trial_id  \
# 450  SUBJ200450   PT100536  CARDIA-9 (Heart Failure)  TRIAL-002
# 533  SUBJ200533   PT100064    NEURA-12 (Alzheimer's)  TRIAL-004
# 249  SUBJ200249   PT100439    ONCO-217 (Lung Cancer)  TRIAL-001
# 257  SUBJ200257   PT100246  CARDIA-9 (Heart Failure)  TRIAL-002
# 226  SUBJ200226   PT101060    NEURA-12 (Alzheimer's)  TRIAL-004
# 402  SUBJ200402   PT101015    NEURA-12 (Alzheimer's)  TRIAL-004
#
#              study_arm  dosage_mg enrollment_date  follow_up_weeks  \
# 450  Active Comparator      150.0      2025-04-30               52
# 533  Active Comparator      150.0      2023-08-30               12
# 249            Placebo      100.0      2024-12-15               52
# 257            Placebo       50.0      2024-03-28                4
# 226          Treatment        NaN      2024-06-04                8
# 402          Treatment      100.0      2023-08-27               12
#
# ...

# %%
A_E.nunique()
# Out:
#                    subject_id  patient_id  trial_name  trial_id  dosage_mg  \
# study_arm
# Active Comparator         139         139           5         5          4
# Placebo                   216         216           5         5          4
# Treatment                 245         245           5         5          4
#
#                    enrollment_date  follow_up_weeks  responded_to_treatment  \
# study_arm
# Active Comparator              126                5                       2
# Placebo                        195                5                       2
# Treatment                      217                5                       2
#
#                    adverse_event  completed_trial
# study_arm
# Active Comparator              5                2
# Placebo                        5                2
# Treatment                      5                2

# %%
## aggregate function

A_E.sum()     ## this is less useful
# Out:
#                                                           subject_id  \
# study_arm
# Active Comparator  SUBJ200004SUBJ200008SUBJ200010SUBJ200024SUBJ20...
# Placebo            SUBJ200001SUBJ200005SUBJ200009SUBJ200012SUBJ20...
# Treatment          SUBJ200000SUBJ200002SUBJ200003SUBJ200006SUBJ20...
#
#                                                           patient_id  \
# study_arm
# Active Comparator  PT100094PT100294PT100107PT100189PT100640PT1001...
# Placebo            PT100311PT100916PT101035PT100857PT101028PT1010...
# Treatment          PT100346PT101154PT101061PT100274PT101021PT1000...
#
#                                                           trial_name  \
# study_arm
# Active Comparator  CARDIA-9 (Heart Failure)NEURA-12 (Alzheimer's)...
# Placebo            RESPIRA-3 (Asthma Biologic)CARDIA-9 (Heart Fai...
# Treatment          ONCO-217 (Lung Cancer)GLYCOX-4 (Type 2 Diabete...
#
#                                                             trial_id  \
# study_arm
# ...

# %%
### aggregation

A_E.agg({'dosage_mg':'mean', 'follow_up_weeks':'sum'})
# Out:
#                     dosage_mg  follow_up_weeks
# study_arm
# Active Comparator  117.829457             2812
# Placebo            119.306931             4336
# Treatment          118.309859             5076

# %%
A_t=PCT.groupby('study_arm')['dosage_mg']
A_t.agg(['min', 'max', 'mean', 'median'])
# Out:
#                     min    max        mean  median
# study_arm
# Active Comparator  50.0  200.0  117.829457   100.0
# Placebo            50.0  200.0  119.306931   100.0
# Treatment          50.0  200.0  118.309859   100.0

# %%
###  can perform a set of functions on each numerical column
A_t=PCT.groupby('study_arm')['follow_up_weeks']

A_t.agg(['min', 'max', 'mean', 'median'])
# Out:
#                    min  max       mean  median
# study_arm
# Active Comparator    4   52  20.230216    12.0
# Placebo              4   52  20.074074    12.0
# Treatment            4   52  20.718367    12.0

# %%
###  adding up both processes

A_E.agg({'dosage_mg':['mean','min', 'min'], 'follow_up_weeks':['sum', 'max', 'min']})
# Out:
#                     dosage_mg             follow_up_weeks
#                          mean   min   min             sum max min
# study_arm
# Active Comparator  117.829457  50.0  50.0            2812  52   4
# Placebo            119.306931  50.0  50.0            4336  52   4
# Treatment          118.309859  50.0  50.0            5076  52   4

# %%
## looping on groups

for group,data in A_E:
    print(data)
# Out:
#      subject_id patient_id                   trial_name   trial_id  \
# 4    SUBJ200004   PT100094     CARDIA-9 (Heart Failure)  TRIAL-002
# 8    SUBJ200008   PT100294       NEURA-12 (Alzheimer's)  TRIAL-004
# 10   SUBJ200010   PT100107       NEURA-12 (Alzheimer's)  TRIAL-004
# 24   SUBJ200024   PT100189   GLYCOX-4 (Type 2 Diabetes)  TRIAL-003
# 31   SUBJ200031   PT100640  RESPIRA-3 (Asthma Biologic)  TRIAL-005
# ..          ...        ...                          ...        ...
# 572  SUBJ200572   PT100335       NEURA-12 (Alzheimer's)  TRIAL-004
# 574  SUBJ200574   PT100591   GLYCOX-4 (Type 2 Diabetes)  TRIAL-003
# 583  SUBJ200583   PT100647     CARDIA-9 (Heart Failure)  TRIAL-002
# 584  SUBJ200584   PT100488       ONCO-217 (Lung Cancer)  TRIAL-001
# 596  SUBJ200596   PT100198     CARDIA-9 (Heart Failure)  TRIAL-002
#
#              study_arm  dosage_mg enrollment_date  follow_up_weeks  \
# 4    Active Comparator      200.0      2023-11-18               12
# ...

# %%
for group,data in A_E:
    print(data['follow_up_weeks'].min())
# Out:
# 4
# 4
# 4

# %%
for group,data in A_E:
    print(data['dosage_mg'].min())
# Out:
# 50.0
# 50.0
# 50.0

# %%
### subject-id in each arm with highest follow up weeks

A_P=PCT.groupby('study_arm')

for group,data in A_P:
    print(group)
    print(data[data['follow_up_weeks']== data['follow_up_weeks'].max()])[['subject_id','follow_up_weeks']]
# Out:
# Active Comparator
#      subject_id patient_id                   trial_name   trial_id  \
# 45   SUBJ200045   PT100377     CARDIA-9 (Heart Failure)  TRIAL-002
# 90   SUBJ200090   PT100378  RESPIRA-3 (Asthma Biologic)  TRIAL-005
# 110  SUBJ200110   PT100210   GLYCOX-4 (Type 2 Diabetes)  TRIAL-003
# 139  SUBJ200139   PT100503  RESPIRA-3 (Asthma Biologic)  TRIAL-005
# 169  SUBJ200169   PT101156     CARDIA-9 (Heart Failure)  TRIAL-002
# 178  SUBJ200178   PT100621       NEURA-12 (Alzheimer's)  TRIAL-004
# 195  SUBJ200195   PT100869  RESPIRA-3 (Asthma Biologic)  TRIAL-005
# 218  SUBJ200218   PT100199       NEURA-12 (Alzheimer's)  TRIAL-004
# 238  SUBJ200238   PT100982       NEURA-12 (Alzheimer's)  TRIAL-004
# 241  SUBJ200241   PT100829  RESPIRA-3 (Asthma Biologic)  TRIAL-005
# 271  SUBJ200271   PT101134       NEURA-12 (Alzheimer's)  TRIAL-004
# 346  SUBJ200346   PT101056   GLYCOX-4 (Type 2 Diabetes)  TRIAL-003
# 362  SUBJ200362   PT100952     CARDIA-9 (Heart Failure)  TRIAL-002
# ...

# %%
### apply function-----> split. apply. combine strategy

PCT.groupby('study_arm')['dosage_mg'].apply(min)
# Out:
# study_arm
# Active Comparator    50.0
# Placebo              50.0
# Treatment            50.0
# Name: dosage_mg, dtype: float64

# %%
### using pateint record dataset

P_record=pd.read_csv('patient_records.csv')
P_record.head(12)
# Out:
#    patient_id first_name  last_name  gender  age blood_type state  \
# 0    PT100000      Sarah    Jackson    Male    0         O+    CA
# 1    PT100001    Jessica      Smith  Female   53         O+    PA
# 2    PT100002       John     Nguyen    Male   70         A+    PA
# 3    PT100003     Robert      Brown    Male   52         O+    PA
# 4    PT100004      Priya      Rossi  Female   36         O+    AZ
# 5    PT100005      Karen  Rodriguez    Male   78         O+    NY
# 6    PT100006      Karen   Gonzalez    Male   35         A+    NC
# 7    PT100007   Jennifer     Garcia    Male   67         B+    MA
# 8    PT100008      Sarah     Nguyen  Female   44         B+    AZ
# 9    PT100009       John        Kim  Female    2         A+    MI
# 10   PT100010   Jennifer   Williams  Female   50         A+    MA
# 11   PT100011      Sarah      Brown    Male    4         B+    OH
#
#    smoking_status insurance_type       primary_condition  height_cm  \
# ...

# %%
## find the no of patients whose name starts with 's' for each group 'gender', 'blood type'

Group1=P_record.groupby(['gender', 'blood_type'])['first_name']

def S_letter(group):
    return group.str.startswith('P').sum()
    

Group1.apply(S_letter)
# Out:
# gender  blood_type
# Female  A+            16
#         A-             1
#         AB+            0
#         AB-            0
#         B+             2
#         B-             1
#         O+            11
#         O-             3
# Male    A+             7
#         A-             1
#         AB+            2
#         AB-            1
#         B+             4
#         B-             0
#         O+            10
#         O-             1
# Other   A+             0
#         A-             0
#         AB+            0
#         B-             0
#         O+             0
#         O-             0
# Name: first_name, dtype: int64

# %%
## find the first name of patients whose primary cond is asthma for each group 'gender' primary condition

def get_names(group):
    return list(group)
    
Asthma_only=P_record[P_record['primary_condition']== 'Asthma']
Group2=Asthma_only.groupby('gender')['first_name']

result=Group2.apply(get_names)
print(result)
# Out:
# gender
# Female    [Ahmed, Sofia, Kwame, Yuki, Linda, Diego, Char...
# Male      [John, Jennifer, Yuki, Yuki, Kwame, Sofia, Sar...
# Other                      [William, Linda, Amara, Jessica]
# Name: first_name, dtype: object

# %%
Asthma_only=P_record[P_record['primary_condition']== 'Asthma']['first_name'].tolist()
Asthma_only
# Out:
# ['John',
#  'Jennifer',
#  'Ahmed',
#  'Yuki',
#  'Sofia',
#  'Yuki',
#  'Kwame',
#  'Kwame',
#  'Sofia',
#  'Sarah',
#  'Hiroshi',
#  'James',
#  'Yuki',
#  'Linda',
#  'Noor',
#  'Diego',
#  'Charles',
#  'Omar',
#  'Noor',
#  'Elena',
#  'Susan',
#  'Charles',
#  'Amara',
#  'Linda',
#  'James',
#  'Barbara',
#  'Amara',
#  'Joseph',
#  'Jessica',
#  'William',
#  'Michael',
#  'Charles',
#  'Sarah',
#  'Linda',
#  'Thomas',
#  'Richard',
#  'Karen',
#  'Robert',
#  'Susan',
#  'Noor',
#  'Fatima',
#  'Amara',
#  'Linda',
#  'Omar',
#  'Noor',
#  'Amara',
#  'Mary',
#  'Mary',
#  'David',
#  'David',
#  'Elena',
#  'Richard',
#  'Elizabeth',
#  'William',
#  'Sofia',
#  'Sarah',
#  'Carlos',
#  'Robert',
#  'Barbara',
#  'Barbara',
#  'Charles',
#  'Sarah',
#  'Charles',
#  'Amara',
#  'Diego',
#  'David',
#  'Susan',
#  'Jennifer',
#  'Carlos',
#  'Elizabeth',
#  'Carlos',
#  'Elizabeth',
#  'Karen',
#  'Yuki',
#  'Barbara',
#  'Fatima',
#  'Mary',
#  'Priya',
#  'Hiroshi',
# ...

# %%
### find all the O+ pateints who have type2  daibetes

type2=P_record[(P_record['primary_condition']== 'Type 2 Diabetes') &  (P_record['blood_type']== 'O+')]
print(type2)
# Out:
#      patient_id first_name  last_name  gender  age blood_type state  \
# 0      PT100000      Sarah    Jackson    Male    0         O+    CA
# 4      PT100004      Priya      Rossi  Female   36         O+    AZ
# 23     PT100023      Amara  Rodriguez    Male   78         O+    VA
# 41     PT100041       Omar      Patel    Male    0         O+    FL
# 45     PT100045     Robert      Smith    Male   84         O+    GA
# ...         ...        ...        ...     ...  ...        ...   ...
# 1109   PT101109   Jennifer      Patel  Female   33         O+    OH
# 1117   PT101117     Ingrid     Miller    Male   85         O+    PA
# 1160   PT101160    Richard   Anderson  Female    6         O+    CA
# 1165   PT101165      Elena   Thompson    Male   24         O+    GA
# 1191   PT101191    Richard    Mueller  Female   28         O+    VA
#
#      smoking_status insurance_type primary_condition  height_cm  weight_kg  \
# ...

# %% [markdown]
# ### Groupby on multiple cols

# %%
P_record.head(2)
# Out:
#   patient_id first_name last_name  gender  age blood_type state  \
# 0   PT100000      Sarah   Jackson    Male    0         O+    CA
# 1   PT100001    Jessica     Smith  Female   53         O+    PA
#
#   smoking_status insurance_type primary_condition  height_cm  weight_kg  \
# 0         Former        Private   Type 2 Diabetes      152.3       81.8
# 1         Former       Medicaid  Anxiety Disorder      183.2       45.6
#
#    systolic_bp  diastolic_bp  heart_rate_bpm last_admission_date
# 0           71            58              75          2024-07-19
# 1          114            89              75          2025-01-16

# %%
Group4=P_record.groupby(['first_name','primary_condition', 'smoking_status'])
Group4.size()
# Out:
# first_name  primary_condition    smoking_status
# Ahmed       Anxiety Disorder     Current           2
#                                  Never             2
#             Asthma               Former            1
#             Atrial Fibrillation  Current           1
#                                  Never             1
#                                                   ..
# Yuki        Hypothyroidism       Former            1
#                                  Never             2
#             Obesity              Never             4
#             Osteoarthritis       Former            1
#                                  Never             1
# Length: 691, dtype: int64

# %%
Group4.get_group(('Priya', 'Asthma', 'Never'))
# Out:
#      patient_id first_name last_name  gender  age blood_type state  \
# 1075   PT101075      Priya     Davis  Female   20         A+    OH
#
#      smoking_status insurance_type primary_condition  height_cm  weight_kg  \
# 1075          Never       Medicaid            Asthma      169.2       81.5
#
#       systolic_bp  diastolic_bp  heart_rate_bpm last_admission_date
# 1075          131            88              76          2024-03-07

# %%
### find all the O+ pateints who have type2  daibetes

Group=P_record.groupby(['gender','blood_type','primary_condition'])
Group.size()
# Out:
# gender  blood_type  primary_condition
# Female  A+          Anxiety Disorder          14
#                     Asthma                    13
#                     Atrial Fibrillation        8
#                     COPD                      13
#                     Chronic Kidney Disease     5
#                                               ..
# Other   O+          GERD                       1
#                     Hypertension               1
#                     Obesity                    1
#         O-          Anxiety Disorder           1
#                     Chronic Kidney Disease     1
# Length: 199, dtype: int64

# %%
Group.get_group(('Female', 'O+', 'Type 2 Diabetes'))
# Out:
#      patient_id first_name  last_name  gender  age blood_type state  \
# 4      PT100004      Priya      Rossi  Female   36         O+    AZ
# 47     PT100047     Ingrid   Anderson  Female   61         O+    TX
# 133    PT100133      Sarah      Patel  Female   16         O+    IL
# 137    PT100137    William     Miller  Female   47         O+    AZ
# 198    PT100198      Susan    Jackson  Female   92         O+    PA
# 220    PT100220        Wei     Garcia  Female   80         O+    FL
# 306    PT100306       Noor     Martin  Female   67         O+    NJ
# 311    PT100311   Patricia   Williams  Female    2         O+    PA
# 397    PT100397     Thomas    Jackson  Female   53         O+    MA
# 399    PT100399       Omar     Garcia  Female   37         O+    VA
# 455    PT100455    William       Khan  Female    7         O+    TX
# 457    PT100457    Jessica        Lee  Female   74         O+    NC
# 474    PT100474      Sofia      Davis  Female   36         O+    GA
# ...

# %%
Group6=P_record.groupby(['gender','smoking_status', 'state'])
Group6.size()
# Out:
# first_name  smoking_status  state
# Ahmed       Current         AZ       1
#                             FL       5
#                             IL       2
#                             NC       2
#                             TX       1
#                                     ..
# Yuki        Never           NY       3
#                             OH       2
#                             PA       1
#                             TX       2
#                             VA       1
# Length: 765, dtype: int64

# %%
gender=input('enter the gender')

Sms_key=input('enter the smokin_status')
state_key=input('enter the state')

key = (gender, Sms_key, state_key)

if key in Group6.groups:
    print(Group6.get_group(key))
else:
    print(f"No group found for {key}")
# Out:
# enter the gender Female
# enter the smokin_status Current
# enter the state VA
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 8
#       4 state_key=input('enter the state')
#       5
#       6 key = (gender, Sms_key, state_key)
#       7
# ----> 8 if key in Group6.groups:
#       9     print(Group6.get_group(key))
#      10 else:
#      11     print(f"No group found for {key}")
#
# NameError: name 'Group6' is not defined

# %%
import pandas as pd

P_record=pd.read_csv('patient_records.csv')
P_record
# Out:
#      patient_id first_name  last_name  gender  age blood_type state  \
# 0      PT100000      Sarah    Jackson    Male    0         O+    CA
# 1      PT100001    Jessica      Smith  Female   53         O+    PA
# 2      PT100002       John     Nguyen    Male   70         A+    PA
# 3      PT100003     Robert      Brown    Male   52         O+    PA
# 4      PT100004      Priya      Rossi  Female   36         O+    AZ
# ...         ...        ...        ...     ...  ...        ...   ...
# 1195   PT101195  Elizabeth      Silva  Female   27        NaN    AZ
# 1196   PT101196     Joseph  Rodriguez  Female   32         O+    NY
# 1197   PT101197   Patricia      White    Male   52         A+    PA
# 1198   PT101198       John       Chen  Female   27         O-    CA
# 1199   PT101199      Susan   Thompson    Male   59         A+    IL
#
#      smoking_status insurance_type       primary_condition  height_cm  \
# 0            Former        Private         Type 2 Diabetes      152.3
# ...

# %%
P_record.head(2)
# Out:
#   patient_id first_name last_name  gender  age blood_type state  \
# 0   PT100000      Sarah   Jackson    Male    0         O+    CA
# 1   PT100001    Jessica     Smith  Female   53         O+    PA
#
#   smoking_status insurance_type primary_condition  height_cm  weight_kg  \
# 0         Former        Private   Type 2 Diabetes      152.3       81.8
# 1         Former       Medicaid  Anxiety Disorder      183.2       45.6
#
#    systolic_bp  diastolic_bp  heart_rate_bpm last_admission_date
# 0           71            58              75          2024-07-19
# 1          114            89              75          2025-01-16

# %%
## find the top 10 pateints with highest heart rate

P_category=P_record.groupby('first_name')['heart_rate_bpm']
P_category.value_counts()
# Out:
# first_name  heart_rate_bpm
# Ahmed       94                4
#             73                4
#             81                3
#             83                3
#             65                3
#                              ..
# Yuki        75                1
#             89                1
#             86                1
#             98                1
#             53                1
# Name: count, Length: 829, dtype: int64

# %%
P_record.groupby('first_name')['heart_rate_bpm'].sum()
# Out:
# first_name
# Ahmed        3041
# Amara        2693
# Barbara      2111
# Carlos       1989
# Charles      2370
# David        2506
# Diego        2084
# Elena        2746
# Elizabeth    3467
# Fatima       2438
# Hiroshi      2756
# Ingrid       2681
# James        2859
# Jennifer     2736
# Jessica      3211
# John         2603
# Joseph       2635
# Karen        2009
# Kwame        2003
# Linda        2212
# Mary         3011
# Michael      2751
# Noor         2747
# Omar         2400
# Patricia     2834
# Priya        1905
# Richard      2511
# Robert       3223
# Sarah        3241
# Sofia        2093
# Susan        2866
# Thomas       2744
# Wei          2744
# William      1926
# Yuki         2538
# Name: heart_rate_bpm, dtype: int64

# %%
P_record.groupby('first_name')['heart_rate_bpm'].sum().sort_values(ascending=False)
# Out:
# first_name
# Elizabeth    3467
# Sarah        3241
# Robert       3223
# Jessica      3211
# Ahmed        3041
# Mary         3011
# Susan        2866
# James        2859
# Patricia     2834
# Hiroshi      2756
# Michael      2751
# Noor         2747
# Elena        2746
# Thomas       2744
# Wei          2744
# Jennifer     2736
# Amara        2693
# Ingrid       2681
# Joseph       2635
# John         2603
# Yuki         2538
# Richard      2511
# David        2506
# Fatima       2438
# Omar         2400
# Charles      2370
# Linda        2212
# Barbara      2111
# Sofia        2093
# Diego        2084
# Karen        2009
# Kwame        2003
# Carlos       1989
# William      1926
# Priya        1905
# Name: heart_rate_bpm, dtype: int64

# %%
P_record.groupby('first_name')['heart_rate_bpm'].sum().sort_values(ascending=False).head(10)
# Out:
# first_name
# Elizabeth    3467
# Sarah        3241
# Robert       3223
# Jessica      3211
# Ahmed        3041
# Mary         3011
# Susan        2866
# James        2859
# Patricia     2834
# Hiroshi      2756
# Name: heart_rate_bpm, dtype: int64

# %%
P_record.groupby('first_name')['heart_rate_bpm'].sum().sort_values(ascending=False).head(1).index[0]
# Out:
# 'Elizabeth'

# %%
P_record.groupby('first_name')['heart_rate_bpm'].count()
# Out:
# first_name
# Ahmed        39
# Amara        36
# Barbara      29
# Carlos       26
# Charles      32
# David        33
# Diego        29
# Elena        37
# Elizabeth    48
# Fatima       31
# Hiroshi      36
# Ingrid       35
# James        37
# Jennifer     38
# Jessica      43
# John         35
# Joseph       34
# Karen        26
# Kwame        27
# Linda        30
# Mary         40
# Michael      36
# Noor         36
# Omar         32
# Patricia     37
# Priya        25
# Richard      34
# Robert       43
# Sarah        42
# Sofia        27
# Susan        35
# Thomas       37
# Wei          35
# William      25
# Yuki         35
# Name: heart_rate_bpm, dtype: int64

# %%
P_T=P_record.groupby(['first_name','primary_condition', 'weight_kg']).sum()
P_T
# Out:
#                                        patient_id last_name  gender  age  \
# first_name primary_condition weight_kg
# Ahmed      Anxiety Disorder  47.4        PT100452       Kim    Male   10
#                              54.0        PT100748  Martinez    Male   94
#                              63.0        PT100381  Gonzalez    Male   88
#                              79.6        PT100477     Rossi    Male   88
#            Asthma            76.0        PT100015     Davis  Female   46
# ...                                           ...       ...     ...  ...
# Yuki       Obesity           75.5        PT100256     Jones    Male    5
#                              85.9        PT100625     Perez  Female   59
#                              95.9        PT100336    Taylor  Female   54
#            Osteoarthritis    70.8        PT100663     White  Female   12
#                              79.3        PT100462    Martin    Male   79
#
# ...

# %%
P_T=P_record.groupby(['primary_condition', 'weight_kg'])['first_name'].sum()
P_T
# Out:
# primary_condition  weight_kg
# Anxiety Disorder   34.4         Jennifer
#                    45.6          Jessica
#                    47.4            Ahmed
#                    51.5          Richard
#                    53.3             Mary
#                                   ...
# Type 2 Diabetes    104.4           Priya
#                    106.1            Omar
#                    113.4          Joseph
#                    116.7           Sofia
#                    116.9            John
# Name: first_name, Length: 1061, dtype: str

# %%
P_record['weight_kg'].sort_values(ascending=False)
# Out:
# 1171    126.2
# 643     125.0
# 108     123.7
# 1072    123.5
# 201     118.1
#         ...
# 1120      NaN
# 1127      NaN
# 1180      NaN
# 1186      NaN
# 1198      NaN
# Name: weight_kg, Length: 1200, dtype: float64

# %%
primary_condition=input('enter the problem')
weight_key=input('enter the weight')


key = (primary_condition, weight_key)

if key in P_T.groups:
    print(P_T.get_group(key))
else:
    print(f"No group found for {key}")
# Out:
# enter the problem Type 2 Daibetes
# enter the weight 125
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 7
#       3
#       4
#       5 key = (primary_condition, weight_key)
#       6
# ----> 7 if key in P_T.groups:
#       8     print(P_T.get_group(key))
#       9 else:
#      10     print(f"No group found for {key}")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'groups'

# %%
df_weight=P_record[P_record['weight_kg']>80]
df_weight[(df_weight['primary_condition']=='Type 2 Diabetes')]
# Out:
#      patient_id first_name  last_name  gender  age blood_type state  \
# 0      PT100000      Sarah    Jackson    Male    0         O+    CA
# 23     PT100023      Amara  Rodriguez    Male   78         O+    VA
# 41     PT100041       Omar      Patel    Male    0         O+    FL
# 56     PT100056      Karen   Gonzalez  Female   79         A+    WA
# 80     PT100080     Joseph      Perez    Male   61        AB-    MA
# ...         ...        ...        ...     ...  ...        ...   ...
# 1038   PT101038    Barbara   Martinez  Female   88         B+    OH
# 1058   PT101058      David   Anderson    Male   79        NaN    PA
# 1109   PT101109   Jennifer      Patel  Female   33         O+    OH
# 1115   PT101115   Jennifer    Mueller  Female   92         A+    NY
# 1131   PT101131      Amara     Wilson    Male    6         A+    NY
#
#      smoking_status insurance_type primary_condition  height_cm  weight_kg  \
# ...

# %%
df_weight.groupby('first_name')['age'].count()
# Out:
# first_name
# Ahmed        10
# Amara         9
# Barbara      15
# Carlos        7
# Charles      11
# David        11
# Diego        10
# Elena        17
# Elizabeth    21
# Fatima       10
# Hiroshi      11
# Ingrid       12
# James         6
# Jennifer     13
# Jessica      17
# John         12
# Joseph       15
# Karen        10
# Kwame        15
# Linda         6
# Mary         11
# Michael      19
# Noor         13
# Omar         14
# Patricia     15
# Priya        12
# Richard       9
# Robert       11
# Sarah        14
# Sofia        14
# Susan         8
# Thomas       16
# Wei          12
# William      10
# Yuki         10
# Name: age, dtype: int64

# %%
df_person=P_record[(P_record['first_name']=='Priya') & (P_record['age']<20)] 

df_person
# Out:
#      patient_id first_name  last_name  gender  age blood_type state  \
# 510    PT100510      Priya      Smith  Female   10         O-    IL
# 545    PT100545      Priya   Anderson  Female   10         A+    PA
# 678    PT100678      Priya       Khan  Female   19         B+    FL
# 948    PT100948      Priya  Rodriguez    Male   11        AB+    PA
# 1116   PT101116      Priya   Anderson  Female   16         A+    IL
# 1128   PT101128      Priya      Smith    Male   17         B+    GA
#
#      smoking_status insurance_type        primary_condition  height_cm  \
# 510         Current       Medicaid           Hypothyroidism      166.9
# 545           Never        Private                     COPD      148.6
# 678             NaN        Private          Type 2 Diabetes      160.5
# 948         Current      Uninsured         Anxiety Disorder      163.1
# 1116         Former        Private                     COPD      167.4
# ...

# %%
## creating a function which can give the age of pateint if primary condition is Anxiety Disorder

P_cat=P_record[P_record['primary_condition']=='Anxiety Disorder']
P_cat.groupby('patient_id')['age'].sum()

def age(primary_condition):
    P_cat=P_record[P_record['primary_condition']=='Anxiety Disorder']
    return P_cat.groupby('patient_id')['age'].sum().sort_values(ascending=False).head(1)

# %%
age('Anxiety Disorder')
# Out:
# patient_id
# PT100216    94
# Name: age, dtype: int64

# %% [markdown]
# ###  Questions

# %%
### What is the average billed_amount for each claim_type in the insurance claims data?

import pandas as pd
import numpy as np

I_C=pd.read_csv('insurance_claims.csv')
I_C.head()
# Out:
#     claim_id patient_id  claim_date diagnosis_code  \
# 0  CLM500000   PT100636  2024-04-20         I25.10
# 1  CLM500001   PT100923  2023-07-17          M54.5
# 2  CLM500002   PT101142  2025-04-06          F41.1
# 3  CLM500003   PT100710  2023-05-11          N39.0
# 4  CLM500004   PT101087  2023-01-25          F41.1
#
#           diagnosis_description        claim_type  provider_npi  \
# 0       Coronary artery disease      Prescription    1000000079
# 1                 Low back pain          Lab Work    1000000105
# 2  Generalized Anxiety Disorder  Outpatient Visit    1000000166
# 3       Urinary tract infection    Emergency Room    1000000195
# 4  Generalized Anxiety Disorder    Inpatient Stay    1000000020
#
#    billed_amount claim_status  approved_amount     payer
# 0          59.13     Approved            53.95     Aetna
# 1          67.59     Approved            67.22  Medicare
# 2         224.00      Pending              NaN  Medicare
# ...

# %%
I_C.groupby('claim_type')['billed_amount'].mean()
# Out:
# claim_type
# Diagnostic Imaging           656.688571
# Emergency Room              1370.042813
# Inpatient Stay              9161.576599
# Lab Work                      92.114545
# Outpatient Visit             181.138000
# Physical Therapy             115.282981
# Prescription                  59.836623
# Specialist Consultation      253.227178
# Surgery                    14922.596129
# Name: billed_amount, dtype: float64

# %%
#### How many patients fall into each primary_condition category?

I_C.groupby('diagnosis_description')['patient_id'].value_counts()
# Out:
# diagnosis_description              patient_id
# Acute upper respiratory infection  PT100063      3
#                                    PT100207      2
#                                    PT100628      2
#                                    PT100005      2
#                                    PT100398      2
#                                                 ..
# Urinary tract infection            PT100898      1
#                                    PT100214      1
#                                    PT100335      1
#                                    PT100348      1
#                                    PT100863      1
# Name: count, Length: 2675, dtype: int64

# %%
P_record=pd.read_csv('patient_records.csv')
P_record.head(2)
# Out:
#   patient_id first_name last_name  gender  age blood_type state  \
# 0   PT100000      Sarah   Jackson    Male    0         O+    CA
# 1   PT100001    Jessica     Smith  Female   53         O+    PA
#
#   smoking_status insurance_type primary_condition  height_cm  weight_kg  \
# 0         Former        Private   Type 2 Diabetes      152.3       81.8
# 1         Former       Medicaid  Anxiety Disorder      183.2       45.6
#
#    systolic_bp  diastolic_bp  heart_rate_bpm last_admission_date
# 0           71            58              75          2024-07-19
# 1          114            89              75          2025-01-16

# %%
###   What is the minimum, maximum, and average heart_rate_bpm for each smoking_status group?

P_category=P_record.groupby('smoking_status')['heart_rate_bpm']
P_category.agg(['min', 'max', 'mean'])
# Out:
#                 min  max       mean
# smoking_status
# Current          44  102  76.186047
# Former           28  107  75.480712
# Never            34  112  75.331768

# %%
## For each test_name in the lab results, compute the mean, min, 
## and max result_value in a single groupby call using

P_LR=pd.read_csv('lab_results.csv')
P_LR.head(2)
# Out:
#       lab_id patient_id          test_name  result_value  reference_range_low  \
# 0  LAB300000   PT101182          ALT (U/L)         13.30                  7.0
# 1  LAB300001   PT100847  Hemoglobin (g/dL)         10.59                 12.0
#
#    reference_range_high    flag   test_date     ordering_facility
# 0                  56.0  Normal  2024-09-20  Northside Clinic Lab
# 1                  17.5     Low  2023-04-22  Northside Clinic Lab

# %%
P_Lab=P_LR.groupby('test_name')['result_value'].agg(['min', 'max', 'mean'])
P_Lab
# Out:
#                                     min     max        mean
# test_name
# ALT (U/L)                          0.10   60.81   27.036576
# Creatinine (mg/dL)                 0.21    1.86    0.973892
# Fasting Glucose (mg/dL)           25.05  195.14   95.456675
# HDL Cholesterol (mg/dL)            6.49   81.49   51.773575
# Hemoglobin (g/dL)                  8.75   17.73   13.393981
# Hemoglobin A1c (%)                 2.55    8.80    5.774949
# LDL Cholesterol (mg/dL)           39.77  177.87  111.998550
# TSH (mIU/L)                        0.10    6.55    2.493494
# Total Cholesterol (mg/dL)         64.13  266.83  185.898472
# White Blood Cell Count (x10^9/L)   1.18   12.93    6.796070

# %%
I_C.head(2)
# Out:
#     claim_id patient_id  claim_date diagnosis_code    diagnosis_description  \
# 0  CLM500000   PT100636  2024-04-20         I25.10  Coronary artery disease
# 1  CLM500001   PT100923  2023-07-17          M54.5            Low back pain
#
#      claim_type  provider_npi  billed_amount claim_status  approved_amount  \
# 0  Prescription    1000000079          59.13     Approved            53.95
# 1      Lab Work    1000000105          67.59     Approved            67.22
#
#       payer
# 0     Aetna
# 1  Medicare

# %%
## For each payer in the insurance claims, find the total 
## billed_amount, total approved_amount, and the count of claims 
##— all in one .agg() call with custom output column names.

result=I_C.groupby('payer').agg(total_bill=('billed_amount', 'sum'), total_approved=('approved_amount', 'sum'), total_claims=('claim_id', 'count'))
result
# Out:
#                       total_bill  total_approved  total_claims
# payer
# Aetna                  556981.24       396594.24           469
# BlueCross BlueShield   636550.03       441190.30           498
# Cigna                  599953.33       422400.44           491
# Medicaid               812209.19       499935.98           533
# Medicare               660670.04       473771.30           499
# UnitedHealthcare       465028.01       329821.68           510

# %%
## Group disease_outbreak.csv by both disease and region — what is the average weekly reported_cases for each disease/region combination? 
## Which region has the highest average for COVID-19 specifically?

P_DO=pd.read_csv('E:\\codedisease_outbreak.csv')
P_DO.head(2)
# Out:
#        disease     region week_start_date  reported_cases  hospitalizations  \
# 0  Influenza A  Northeast      2024-01-01              95                 9
# 1  Influenza A  Northeast      2024-01-08              93                 2
#
#    deaths
# 0       0
# 1       0

# %%
Dise_o=P_DO.groupby(['disease', 'region'])['reported_cases'].mean()
Dise_o
# Out:
# disease      region
# COVID-19     Midwest      167.085714
#              Northeast    117.038095
#              Southeast    189.961905
#              Southwest    286.390476
#              West         242.761905
# Influenza A  Midwest       35.409524
#              Northeast     44.980952
#              Southeast     19.990476
#              Southwest     49.819048
#              West          46.600000
# Measles      Midwest      198.961905
#              Northeast    491.466667
#              Southeast    358.000000
#              Southwest    232.609524
#              West         263.809524
# Norovirus    Midwest      254.609524
#              Northeast    126.085714
#              Southeast    149.742857
#              Southwest    167.923810
#              West         115.838095
# Pertussis    Midwest      122.847619
#              Northeast    224.228571
#              Southeast    172.142857
#              Southwest    138.085714
#              West         141.819048
# ...

# %%
## . Group lab_results.csv by test_name and flag — how many "High," "Low," and "Normal" results exist for each test?

P_LR.head(2)
# Out:
#       lab_id patient_id          test_name  result_value  reference_range_low  \
# 0  LAB300000   PT101182          ALT (U/L)         13.30                  7.0
# 1  LAB300001   PT100847  Hemoglobin (g/dL)         10.59                 12.0
#
#    reference_range_high    flag   test_date     ordering_facility
# 0                  56.0  Normal  2024-09-20  Northside Clinic Lab
# 1                  17.5     Low  2023-04-22  Northside Clinic Lab

# %%
lab_res=P_LR.groupby('test_name')['flag'].value_counts()
lab_res
# Out:
# test_name                         flag
# ALT (U/L)                         Normal    386
#                                   Low        12
#                                   High        5
# Creatinine (mg/dL)                Normal    319
#                                   High       60
#                                   Low        45
# Fasting Glucose (mg/dL)           Normal    187
#                                   High      173
#                                   Low        46
# HDL Cholesterol (mg/dL)           Normal    343
#                                   Low        57
# Hemoglobin (g/dL)                 Normal    354
#                                   Low        72
#                                   High        1
# Hemoglobin A1c (%)                High      206
#                                   Normal    162
#                                   Low        24
# LDL Cholesterol (mg/dL)           High      259
#                                   Normal    134
# ...

# %%
###  Which 5 radiologist_ids reviewed the most imaging studies? 
##(Hint: groupby().size().sort_values(ascending=False).head())

P_scan=pd.read_csv('E:\\code\\imaging.csv')
P_scan.head(2)
# Out:
#     image_id patient_id modality body_part  study_date radiologist_id  \
# 0  IMG400000   PT100779      MRI     Spine  2023-07-16         RAD025
# 1  IMG400001   PT100870    X-Ray      Hand  2024-07-06         RAD014
#
#                 finding_summary  file_size_mb image_resolution  contrast_used
# 0  Nodule - recommend follow-up         278.3          512x512          False
# 1  Nodule - recommend follow-up           1.5        2048x2048          False

# %%
image=P_scan.groupby('radiologist_id')['modality'].size().sort_values(ascending=False).head(5)
image
# Out:
# radiologist_id
# RAD004    106
# RAD025    103
# RAD005    102
# RAD009     98
# RAD011     97
# Name: modality, dtype: int64

# %%
### Using groupby().filter(), find only the claim_type groups 
## where the average billed_amount exceeds $1,000.

I_C.head(2)
# Out:
#     claim_id patient_id  claim_date diagnosis_code    diagnosis_description  \
# 0  CLM500000   PT100636  2024-04-20         I25.10  Coronary artery disease
# 1  CLM500001   PT100923  2023-07-17          M54.5            Low back pain
#
#      claim_type  provider_npi  billed_amount claim_status  approved_amount  \
# 0  Prescription    1000000079          59.13     Approved            53.95
# 1      Lab Work    1000000105          67.59     Approved            67.22
#
#       payer
# 0     Aetna
# 1  Medicare

# %%
Insurance=I_C.groupby('claim_type')['billed_amount'].mean()>1000
Insurance
# Out:
# claim_type
# Diagnostic Imaging         False
# Emergency Room              True
# Inpatient Stay              True
# Lab Work                   False
# Outpatient Visit           False
# Physical Therapy           False
# Prescription               False
# Specialist Consultation    False
# Surgery                     True
# Name: billed_amount, dtype: bool

# %%
I_C['billed_amount'].mean()
# Out:
# np.float64(1243.79728)

# %%
Insurance=I_C.groupby('claim_type').filter(lambda x: x['billed_amount'].mean()>1000)
Insurance
# Out:
#        claim_id patient_id  claim_date diagnosis_code  \
# 3     CLM500003   PT100710  2023-05-11          N39.0
# 4     CLM500004   PT101087  2023-01-25          F41.1
# 9     CLM500009   PT100356  2025-01-27          J06.9
# 10    CLM500010   PT100606  2023-03-24          E11.9
# 19    CLM500019   PT100825  2025-11-08            I10
# ...         ...        ...         ...            ...
# 2992  CLM502992   PT100254  2025-08-01          F32.9
# 2993  CLM502993   PT100836  2024-12-14          F32.9
# 2995  CLM502995   PT100760  2023-05-22          E11.9
# 2996  CLM502996   PT100009  2024-11-07          E11.9
# 2999  CLM502999   PT100664  2023-05-26          M17.9
#
#                       diagnosis_description      claim_type  provider_npi  \
# 3                   Urinary tract infection  Emergency Room    1000000195
# 4              Generalized Anxiety Disorder  Inpatient Stay    1000000020
# 9         Acute upper respiratory infection  Inpatient Stay    1000000182
# ...

# %%
Insurance.value_counts()
# Out:
# billed_amount
# False    6
# True     3
# Name: count, dtype: int64

# %%
## For each patient, calculate how their weight_kg compares to the average weight of patients with 
## the same primary_condition (i.e., their weight minus the group average). Use groupby().transform().

P_record.head(1)
# Out:
#   patient_id first_name last_name gender  age blood_type state smoking_status  \
# 0   PT100000      Sarah   Jackson   Male    0         O+    CA         Former
#
#   insurance_type primary_condition  height_cm  weight_kg  systolic_bp  \
# 0        Private   Type 2 Diabetes      152.3       81.8           71
#
#    diastolic_bp  heart_rate_bpm last_admission_date
# 0            58              75          2024-07-19
